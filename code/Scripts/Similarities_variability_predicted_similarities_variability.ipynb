# %% [markdown]
# # Assessment of in-batch similarity variability based on Twin Network calculated similarities

# %% [markdown]
# # Table of Contents
#
# * [General](#first-bullet)
# * [Load paths](#second-bullet)
# * [Load model](#third-bullet)
# * [Calculate embeddings](#fourth-bullet)
# * [(Optional) Save embeddings](#fifth-bullet)
# * [Calculate similarities](#sixth-bullet)
# * [(Optional) Save similarities](#seventh-bullet)
# * [Plot distribution of similarities at selected sequence indices](#eigth-bullet)
# * [Plot distribution of similarities for complete sequence](#ninth-bullet)

# %% [markdown]
# ## General <a class="anchor" id="first-bullet"></a>

# %% [markdown]
# General imports and class definitions

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Load paths from config file

# %%
from twinnet_tools.tnconfig import ProjectConfig

config = ProjectConfig("twinnet_config")

# %%
dir_root_scripts = config.json["dir_scripts"]
path_model_zebrafish = config.json["dir_model_zebrafish_more_data"]

config_paths_script = config.json["Similarities_variability_predicted_similarities_variability"]
dir_data_src = config_paths_script["dir_data_src"]
path_src_data_test_json = config_paths_script["path_src_data_test_json"]
path_dst = config_paths_script["dir_data_dst"]

# %% [markdown]
# Import Python packages

# %%
import glob
import matplotlib as mpl
import numpy as np
import pandas as pd
import sys

sys.path.append(dir_root_scripts)
from twinnet_tools.tngeneral import TNToolsGeneral
from twinnet_tools.tninference import TNToolsEmbeddings
from twinnet_tools.tninference import TNToolsPaths
from twinnet_tools.tninference import TNToolsSimilarities
from twinnet_tools.tnmodel import TNToolsNetwork
from twinnet_tools.tnplot import TNToolsPlot

from pathlib import Path

# %% [markdown]
# Prepare class instances

# %%
tools_general = TNToolsGeneral()
tools_embeddings = TNToolsEmbeddings(size_img=224, size_img_min=300)
tools_model = TNToolsNetwork()
tools_paths = TNToolsPaths()
tools_similarities = TNToolsSimilarities()
tools_plot = TNToolsPlot()

# %% [markdown]
# Adjust matplotlib parameters to save plots as .svg files.

# %%
new_rc_params = {'text.usetex': False,
                'svg.fonttype': 'none'}
mpl.rcParams.update(new_rc_params)

# %% [markdown]
# ## Load paths <a class="anchor" id="second-bullet"></a>

# %% [markdown]
# Load test data paths

# %%
embryos_normal = [f"{dir_data_src}/{p[2:]}".replace('//', '/') 
                  for p in sorted(tools_general.fn_json_load(
                      path_src_data_test_json)['normal_bright_complete'])
                 ]

# %% [markdown]
# Load paths of images sorted by image indices

# %%
images_embryos = tools_paths.dirs_to_images_sort_indices(embryos_normal)
# Out:
# [INFO] Number of timepoints/images: 360/77

# %% [markdown]
# Specifiy directory to save output files to

# %%
dir_dst_embeddings = f"{path_dst}/embeddings"
dir_dst_similarities = f"{path_dst}/similarities"

# %%
dir_dst_embeddings_path = Path( dir_dst_embeddings )
dir_dst_embeddings_path.mkdir(parents=True, exist_ok=True)

dir_dst_similarities_path = Path( dir_dst_similarities )
dir_dst_similarities_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Load model <a class="anchor" id="third-bullet"></a>

# %%
tn_model_embedding = tools_model.tn_embedding_load(path_model_zebrafish)
# Out:
# 2023-04-27 19:16:50.805535: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-27 19:16:50.847117: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-27 19:16:50.850099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-27 19:16:50.853222: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-27 19:16:50.853783: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-27 19:16:50.856711: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-27 19:16:50.859522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-27 19:16:52.127885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-27 19:16:52.129794: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-27 19:16:52.131448: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-27 19:16:52.133143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13611 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5

# %% [markdown]
# ## Calculate embeddings <a class="anchor" id="fourth-bullet"></a>

# %% [markdown]
# Calculate embeddings for all images at each index.

# %%
embeddings = dict()
for _k_tp, _v_tp in images_embryos.items():
    print(f'Tp {_k_tp}/{len(images_embryos.keys())}'.ljust(50))
    embeddings[_k_tp] = tools_embeddings.list_to_embeddings_keep_order(
        images_embryos[_k_tp], tn_model_embedding)
# Out:
# Tp 0/360
# [LOADING] Image arrays 9/77 ...
# 2023-04-25 17:46:01.987652: W tensorflow_io/core/kernels/audio_video_mp3_kernels.cc:271] libmp3lame.so.0 or lame functions are not available
# 2023-04-25 17:46:01.987973: I tensorflow_io/core/kernels/cpu_check.cc:128] Your CPU supports instructions that this TensorFlow IO binary was not compiled to use: AVX2 AVX512F FMA
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# [LOADING][Embeddings]0001/0004
# 2023-04-25 17:46:03.274137: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# [DONE][Embeddings] 0004/0004
# Tp 1/360
# [DONE][Embeddings] 0004/0004
# Tp 2/360
# [DONE][Embeddings] 0004/0004
# Tp 3/360
# [DONE][Embeddings] 0004/0004
# Tp 4/360
# [DONE][Embeddings] 0004/0004
# Tp 5/360
# [DONE][Embeddings] 0004/0004
# Tp 6/360
# [DONE][Embeddings] 0004/0004
# Tp 7/360
# [DONE][Embeddings] 0004/0004
# Tp 8/360
# [DONE][Embeddings] 0004/0004
# Tp 9/360
# [DONE][Embeddings] 0004/0004
# Tp 10/360
# [DONE][Embeddings] 0004/0004
# Tp 11/360
# [DONE][Embeddings] 0004/0004
# Tp 12/360
# [DONE][Embeddings] 0004/0004
# Tp 13/360
# [DONE][Embeddings] 0004/0004
# Tp 14/360
# [DONE][Embeddings] 0004/0004
# Tp 15/360
# [DONE][Embeddings] 0004/0004
# Tp 16/360
# [DONE][Embeddings] 0004/0004
# Tp 17/360
# [DONE][Embeddings] 0004/0004
# Tp 18/360
# [DONE][Embeddings] 0004/0004
# Tp 19/360
# [DONE][Embeddings] 0004/0004
# Tp 20/360
# [DONE][Embeddings] 0004/0004
# Tp 21/360
# [DONE][Embeddings] 0004/0004
# Tp 22/360
# [DONE][Embeddings] 0004/0004
# Tp 23/360
# [DONE][Embeddings] 0004/0004
# Tp 24/360
# [DONE][Embeddings] 0004/0004
# Tp 25/360
# [DONE][Embeddings] 0004/0004
# Tp 26/360
# [DONE][Embeddings] 0004/0004
# Tp 27/360
# [DONE][Embeddings] 0004/0004
# Tp 28/360
# [DONE][Embeddings] 0004/0004
# Tp 29/360
# [DONE][Embeddings] 0004/0004
# Tp 30/360
# [DONE][Embeddings] 0004/0004
# Tp 31/360
# [DONE][Embeddings] 0004/0004
# Tp 32/360
# [DONE][Embeddings] 0004/0004
# Tp 33/360
# [DONE][Embeddings] 0004/0004
# Tp 34/360
# [DONE][Embeddings] 0004/0004
# Tp 35/360
# [DONE][Embeddings] 0004/0004
# Tp 36/360
# [DONE][Embeddings] 0004/0004
# Tp 37/360
# [DONE][Embeddings] 0004/0004
# Tp 38/360
# [DONE][Embeddings] 0004/0004
# Tp 39/360
# [DONE][Embeddings] 0004/0004
# Tp 40/360
# [DONE][Embeddings] 0004/0004
# Tp 41/360
# [DONE][Embeddings] 0004/0004
# Tp 42/360
# [DONE][Embeddings] 0004/0004
# Tp 43/360
# [DONE][Embeddings] 0004/0004
# Tp 44/360
# [DONE][Embeddings] 0004/0004
# Tp 45/360
# [DONE][Embeddings] 0004/0004
# Tp 46/360
# [DONE][Embeddings] 0004/0004
# Tp 47/360
# [DONE][Embeddings] 0004/0004
# Tp 48/360
# [DONE][Embeddings] 0004/0004
# Tp 49/360
# [DONE][Embeddings] 0004/0004
# Tp 50/360
# [LOADING] Image arrays 8/77 ...
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# [DONE][Embeddings] 0004/0004
# Tp 51/360
# [DONE][Embeddings] 0004/0004
# Tp 52/360
# [DONE][Embeddings] 0004/0004
# Tp 53/360
# [DONE][Embeddings] 0004/0004
# Tp 54/360
# [DONE][Embeddings] 0004/0004
# Tp 55/360
# [DONE][Embeddings] 0004/0004
# Tp 56/360
# [DONE][Embeddings] 0004/0004
# Tp 57/360
# [DONE][Embeddings] 0004/0004
# Tp 58/360
# [DONE][Embeddings] 0004/0004
# Tp 59/360
# [DONE][Embeddings] 0004/0004
# Tp 60/360
# [DONE][Embeddings] 0004/0004
# Tp 61/360
# [DONE][Embeddings] 0004/0004
# Tp 62/360
# [DONE][Embeddings] 0004/0004
# Tp 63/360
# [DONE][Embeddings] 0004/0004
# Tp 64/360
# [DONE][Embeddings] 0004/0004
# Tp 65/360
# [DONE][Embeddings] 0004/0004
# Tp 66/360
# [DONE][Embeddings] 0004/0004
# Tp 67/360
# [DONE][Embeddings] 0004/0004
# Tp 68/360
# [DONE][Embeddings] 0004/0004
# Tp 69/360
# [DONE][Embeddings] 0004/0004
# Tp 70/360
# [DONE][Embeddings] 0004/0004
# Tp 71/360
# [DONE][Embeddings] 0004/0004
# Tp 72/360
# [DONE][Embeddings] 0004/0004
# Tp 73/360
# [DONE][Embeddings] 0004/0004
# Tp 74/360
# [DONE][Embeddings] 0004/0004
# Tp 75/360
# [DONE][Embeddings] 0004/0004
# Tp 76/360
# [DONE][Embeddings] 0004/0004
# Tp 77/360
# [DONE][Embeddings] 0004/0004
# Tp 78/360
# [DONE][Embeddings] 0004/0004
# Tp 79/360
# [DONE][Embeddings] 0004/0004
# Tp 80/360
# [DONE][Embeddings] 0004/0004
# Tp 81/360
# [DONE][Embeddings] 0004/0004
# Tp 82/360
# [DONE][Embeddings] 0004/0004
# Tp 83/360
# [DONE][Embeddings] 0004/0004
# Tp 84/360
# [DONE][Embeddings] 0004/0004
# Tp 85/360
# [DONE][Embeddings] 0004/0004
# Tp 86/360
# [DONE][Embeddings] 0004/0004
# Tp 87/360
# [DONE][Embeddings] 0004/0004
# Tp 88/360
# [DONE][Embeddings] 0004/0004
# Tp 89/360
# [DONE][Embeddings] 0004/0004
# Tp 90/360
# [DONE][Embeddings] 0004/0004
# Tp 91/360
# [DONE][Embeddings] 0004/0004
# Tp 92/360
# [DONE][Embeddings] 0004/0004
# Tp 93/360
# [DONE][Embeddings] 0004/0004
# Tp 94/360
# [DONE][Embeddings] 0004/0004
# Tp 95/360
# [DONE][Embeddings] 0004/0004
# Tp 96/360
# [DONE][Embeddings] 0004/0004
# Tp 97/360
# [DONE][Embeddings] 0004/0004
# Tp 98/360
# [DONE][Embeddings] 0004/0004
# Tp 99/360
# [DONE][Embeddings] 0004/0004
# Tp 100/360
# [LOADING] Image arrays 26/77 ...
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# [DONE][Embeddings] 0004/0004
# Tp 101/360
# [DONE][Embeddings] 0004/0004
# Tp 102/360
# [DONE][Embeddings] 0004/0004
# Tp 103/360
# [DONE][Embeddings] 0004/0004
# Tp 104/360
# [DONE][Embeddings] 0004/0004
# Tp 105/360
# [DONE][Embeddings] 0004/0004
# Tp 106/360
# [DONE][Embeddings] 0004/0004
# Tp 107/360
# [DONE][Embeddings] 0004/0004
# Tp 108/360
# [DONE][Embeddings] 0004/0004
# Tp 109/360
# [DONE][Embeddings] 0004/0004
# Tp 110/360
# [DONE][Embeddings] 0004/0004
# Tp 111/360
# [DONE][Embeddings] 0004/0004
# Tp 112/360
# [DONE][Embeddings] 0004/0004
# Tp 113/360
# [DONE][Embeddings] 0004/0004
# Tp 114/360
# [DONE][Embeddings] 0004/0004
# Tp 115/360
# [DONE][Embeddings] 0004/0004
# Tp 116/360
# [DONE][Embeddings] 0004/0004
# Tp 117/360
# [DONE][Embeddings] 0004/0004
# Tp 118/360
# [DONE][Embeddings] 0004/0004
# Tp 119/360
# [DONE][Embeddings] 0004/0004
# Tp 120/360
# [DONE][Embeddings] 0004/0004
# Tp 121/360
# [DONE][Embeddings] 0004/0004
# Tp 122/360
# [DONE][Embeddings] 0004/0004
# Tp 123/360
# [DONE][Embeddings] 0004/0004
# Tp 124/360
# [DONE][Embeddings] 0004/0004
# Tp 125/360
# [DONE][Embeddings] 0004/0004
# Tp 126/360
# [DONE][Embeddings] 0004/0004
# Tp 127/360
# [DONE][Embeddings] 0004/0004
# Tp 128/360
# [DONE][Embeddings] 0004/0004
# Tp 129/360
# [DONE][Embeddings] 0004/0004
# Tp 130/360
# [DONE][Embeddings] 0004/0004
# Tp 131/360
# [DONE][Embeddings] 0004/0004
# Tp 132/360
# [DONE][Embeddings] 0004/0004
# Tp 133/360
# [DONE][Embeddings] 0004/0004
# Tp 134/360
# [DONE][Embeddings] 0004/0004
# Tp 135/360
# [DONE][Embeddings] 0004/0004
# Tp 136/360
# [DONE][Embeddings] 0004/0004
# Tp 137/360
# [DONE][Embeddings] 0004/0004
# Tp 138/360
# [DONE][Embeddings] 0004/0004
# Tp 139/360
# [DONE][Embeddings] 0004/0004
# Tp 140/360
# [DONE][Embeddings] 0004/0004
# Tp 141/360
# [DONE][Embeddings] 0004/0004
# Tp 142/360
# [DONE][Embeddings] 0004/0004
# Tp 143/360
# [DONE][Embeddings] 0004/0004
# Tp 144/360
# [DONE][Embeddings] 0004/0004
# Tp 145/360
# [DONE][Embeddings] 0004/0004
# Tp 146/360
# [DONE][Embeddings] 0004/0004
# Tp 147/360
# [DONE][Embeddings] 0004/0004
# Tp 148/360
# [DONE][Embeddings] 0004/0004
# Tp 149/360
# [DONE][Embeddings] 0004/0004
# Tp 150/360
# [DONE][Embeddings] 0004/0004
# Tp 151/360
# [DONE][Embeddings] 0004/0004
# Tp 152/360
# [DONE][Embeddings] 0004/0004
# Tp 153/360
# [DONE][Embeddings] 0004/0004
# Tp 154/360
# [DONE][Embeddings] 0004/0004
# Tp 155/360
# [DONE][Embeddings] 0004/0004
# Tp 156/360
# [DONE][Embeddings] 0004/0004
# Tp 157/360
# [DONE][Embeddings] 0004/0004
# Tp 158/360
# [DONE][Embeddings] 0004/0004
# Tp 159/360
# [DONE][Embeddings] 0004/0004
# Tp 160/360
# [DONE][Embeddings] 0004/0004
# Tp 161/360
# [DONE][Embeddings] 0004/0004
# Tp 162/360
# [DONE][Embeddings] 0004/0004
# Tp 163/360
# [DONE][Embeddings] 0004/0004
# Tp 164/360
# [DONE][Embeddings] 0004/0004
# Tp 165/360
# [DONE][Embeddings] 0004/0004
# Tp 166/360
# [DONE][Embeddings] 0004/0004
# Tp 167/360
# [DONE][Embeddings] 0004/0004
# Tp 168/360
# [DONE][Embeddings] 0004/0004
# Tp 169/360
# [DONE][Embeddings] 0004/0004
# Tp 170/360
# [DONE][Embeddings] 0004/0004
# Tp 171/360
# [DONE][Embeddings] 0004/0004
# Tp 172/360
# [DONE][Embeddings] 0004/0004
# Tp 173/360
# [DONE][Embeddings] 0004/0004
# Tp 174/360
# [DONE][Embeddings] 0004/0004
# Tp 175/360
# [DONE][Embeddings] 0004/0004
# Tp 176/360
# [DONE][Embeddings] 0004/0004
# Tp 177/360
# [DONE][Embeddings] 0004/0004
# Tp 178/360
# [DONE][Embeddings] 0004/0004
# Tp 179/360
# [DONE][Embeddings] 0004/0004
# Tp 180/360
# [DONE][Embeddings] 0004/0004
# Tp 181/360
# [DONE][Embeddings] 0004/0004
# Tp 182/360
# [DONE][Embeddings] 0004/0004
# Tp 183/360
# [DONE][Embeddings] 0004/0004
# Tp 184/360
# [DONE][Embeddings] 0004/0004
# Tp 185/360
# [DONE][Embeddings] 0004/0004
# Tp 186/360
# [DONE][Embeddings] 0004/0004
# Tp 187/360
# [DONE][Embeddings] 0004/0004
# Tp 188/360
# [DONE][Embeddings] 0004/0004
# Tp 189/360
# [DONE][Embeddings] 0004/0004
# Tp 190/360
# [DONE][Embeddings] 0004/0004
# Tp 191/360
# [DONE][Embeddings] 0004/0004
# Tp 192/360
# [DONE][Embeddings] 0004/0004
# Tp 193/360
# [DONE][Embeddings] 0004/0004
# Tp 194/360
# [DONE][Embeddings] 0004/0004
# Tp 195/360
# [DONE][Embeddings] 0004/0004
# Tp 196/360
# [DONE][Embeddings] 0004/0004
# Tp 197/360
# [DONE][Embeddings] 0004/0004
# Tp 198/360
# [DONE][Embeddings] 0004/0004
# Tp 199/360
# [DONE][Embeddings] 0004/0004
# Tp 200/360
# [DONE][Embeddings] 0004/0004
# Tp 201/360
# [DONE][Embeddings] 0004/0004
# Tp 202/360
# [DONE][Embeddings] 0004/0004
# Tp 203/360
# [DONE][Embeddings] 0004/0004
# Tp 204/360
# [DONE][Embeddings] 0004/0004
# Tp 205/360
# [DONE][Embeddings] 0004/0004
# Tp 206/360
# [DONE][Embeddings] 0004/0004
# Tp 207/360
# [DONE][Embeddings] 0004/0004
# Tp 208/360
# [DONE][Embeddings] 0004/0004
# Tp 209/360
# [DONE][Embeddings] 0004/0004
# Tp 210/360
# [DONE][Embeddings] 0004/0004
# Tp 211/360
# [DONE][Embeddings] 0004/0004
# Tp 212/360
# [DONE][Embeddings] 0004/0004
# Tp 213/360
# [DONE][Embeddings] 0004/0004
# Tp 214/360
# [DONE][Embeddings] 0004/0004
# Tp 215/360
# [DONE][Embeddings] 0004/0004
# Tp 216/360
# [DONE][Embeddings] 0004/0004
# Tp 217/360
# [DONE][Embeddings] 0004/0004
# Tp 218/360
# [DONE][Embeddings] 0004/0004
# Tp 219/360
# [DONE][Embeddings] 0004/0004
# Tp 220/360
# [DONE][Embeddings] 0004/0004
# Tp 221/360
# [DONE][Embeddings] 0004/0004
# Tp 222/360
# [DONE][Embeddings] 0004/0004
# Tp 223/360
# [DONE][Embeddings] 0004/0004
# Tp 224/360
# [DONE][Embeddings] 0004/0004
# Tp 225/360
# [DONE][Embeddings] 0004/0004
# Tp 226/360
# [DONE][Embeddings] 0004/0004
# Tp 227/360
# [DONE][Embeddings] 0004/0004
# Tp 228/360
# [DONE][Embeddings] 0004/0004
# Tp 229/360
# [DONE][Embeddings] 0004/0004
# Tp 230/360
# [DONE][Embeddings] 0004/0004
# Tp 231/360
# [DONE][Embeddings] 0004/0004
# Tp 232/360
# [DONE][Embeddings] 0004/0004
# Tp 233/360
# [DONE][Embeddings] 0004/0004
# Tp 234/360
# [DONE][Embeddings] 0004/0004
# Tp 235/360
# [DONE][Embeddings] 0004/0004
# Tp 236/360
# [DONE][Embeddings] 0004/0004
# Tp 237/360
# [DONE][Embeddings] 0004/0004
# Tp 238/360
# [DONE][Embeddings] 0004/0004
# Tp 239/360
# [DONE][Embeddings] 0004/0004
# Tp 240/360
# [DONE][Embeddings] 0004/0004
# Tp 241/360
# [DONE][Embeddings] 0004/0004
# Tp 242/360
# [DONE][Embeddings] 0004/0004
# Tp 243/360
# [DONE][Embeddings] 0004/0004
# Tp 244/360
# [DONE][Embeddings] 0004/0004
# Tp 245/360
# [DONE][Embeddings] 0004/0004
# Tp 246/360
# [DONE][Embeddings] 0004/0004
# Tp 247/360
# [DONE][Embeddings] 0004/0004
# Tp 248/360
# [DONE][Embeddings] 0004/0004
# Tp 249/360
# [DONE][Embeddings] 0004/0004
# Tp 250/360
# [LOADING] Image arrays 9/77 ...
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# [DONE][Embeddings] 0004/0004
# Tp 251/360
# [DONE][Embeddings] 0004/0004
# Tp 252/360
# [DONE][Embeddings] 0004/0004
# Tp 253/360
# [DONE][Embeddings] 0004/0004
# Tp 254/360
# [DONE][Embeddings] 0004/0004
# Tp 255/360
# [DONE][Embeddings] 0004/0004
# Tp 256/360
# [DONE][Embeddings] 0004/0004
# Tp 257/360
# [DONE][Embeddings] 0004/0004
# Tp 258/360
# [DONE][Embeddings] 0004/0004
# Tp 259/360
# [DONE][Embeddings] 0004/0004
# Tp 260/360
# [DONE][Embeddings] 0004/0004
# Tp 261/360
# [DONE][Embeddings] 0004/0004
# Tp 262/360
# [DONE][Embeddings] 0004/0004
# Tp 263/360
# [DONE][Embeddings] 0004/0004
# Tp 264/360
# [DONE][Embeddings] 0004/0004
# Tp 265/360
# [DONE][Embeddings] 0004/0004
# Tp 266/360
# [DONE][Embeddings] 0004/0004
# Tp 267/360
# [DONE][Embeddings] 0004/0004
# Tp 268/360
# [DONE][Embeddings] 0004/0004
# Tp 269/360
# [DONE][Embeddings] 0004/0004
# Tp 270/360
# [DONE][Embeddings] 0004/0004
# Tp 271/360
# [DONE][Embeddings] 0004/0004
# Tp 272/360
# [DONE][Embeddings] 0004/0004
# Tp 273/360
# [DONE][Embeddings] 0004/0004
# Tp 274/360
# [DONE][Embeddings] 0004/0004
# Tp 275/360
# [DONE][Embeddings] 0004/0004
# Tp 276/360
# [DONE][Embeddings] 0004/0004
# Tp 277/360
# [DONE][Embeddings] 0004/0004
# Tp 278/360
# [DONE][Embeddings] 0004/0004
# Tp 279/360
# [DONE][Embeddings] 0004/0004
# Tp 280/360
# [DONE][Embeddings] 0004/0004
# Tp 281/360
# [DONE][Embeddings] 0004/0004
# Tp 282/360
# [DONE][Embeddings] 0004/0004
# Tp 283/360
# [DONE][Embeddings] 0004/0004
# Tp 284/360
# [DONE][Embeddings] 0004/0004
# Tp 285/360
# [DONE][Embeddings] 0004/0004
# Tp 286/360
# [DONE][Embeddings] 0004/0004
# Tp 287/360
# [DONE][Embeddings] 0004/0004
# Tp 288/360
# [DONE][Embeddings] 0004/0004
# Tp 289/360
# [DONE][Embeddings] 0004/0004
# Tp 290/360
# [DONE][Embeddings] 0004/0004
# Tp 291/360
# [DONE][Embeddings] 0004/0004
# Tp 292/360
# [DONE][Embeddings] 0004/0004
# Tp 293/360
# [DONE][Embeddings] 0004/0004
# Tp 294/360
# [DONE][Embeddings] 0004/0004
# Tp 295/360
# [DONE][Embeddings] 0004/0004
# Tp 296/360
# [DONE][Embeddings] 0004/0004
# Tp 297/360
# [DONE][Embeddings] 0004/0004
# Tp 298/360
# [DONE][Embeddings] 0004/0004
# Tp 299/360
# [DONE][Embeddings] 0004/0004
# Tp 300/360
# [LOADING] Image arrays 16/72 ...
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# TIFFReadDirectory: Warning, Unknown field with tag 37724 (0x935c) encountered.
# [DONE][Embeddings] 0004/0004
# Tp 301/360
# [DONE][Embeddings] 0004/0004
# Tp 302/360
# [DONE][Embeddings] 0004/0004
# Tp 303/360
# [DONE][Embeddings] 0004/0004
# Tp 304/360
# [DONE][Embeddings] 0004/0004
# Tp 305/360
# [DONE][Embeddings] 0004/0004
# Tp 306/360
# [DONE][Embeddings] 0004/0004
# Tp 307/360
# [DONE][Embeddings] 0004/0004
# Tp 308/360
# [DONE][Embeddings] 0004/0004
# Tp 309/360
# [DONE][Embeddings] 0004/0004
# Tp 310/360
# [DONE][Embeddings] 0004/0004
# Tp 311/360
# [DONE][Embeddings] 0004/0004
# Tp 312/360
# [DONE][Embeddings] 0004/0004
# Tp 313/360
# [DONE][Embeddings] 0004/0004
# Tp 314/360
# [DONE][Embeddings] 0004/0004
# Tp 315/360
# [DONE][Embeddings] 0004/0004
# Tp 316/360
# [DONE][Embeddings] 0004/0004
# Tp 317/360
# [DONE][Embeddings] 0004/0004
# Tp 318/360
# [DONE][Embeddings] 0004/0004
# Tp 319/360
# [DONE][Embeddings] 0004/0004
# Tp 320/360
# [DONE][Embeddings] 0004/0004
# Tp 321/360
# [DONE][Embeddings] 0004/0004
# Tp 322/360
# [DONE][Embeddings] 0004/0004
# Tp 323/360
# [DONE][Embeddings] 0004/0004
# Tp 324/360
# [DONE][Embeddings] 0004/0004
# Tp 325/360
# [DONE][Embeddings] 0004/0004
# Tp 326/360
# [DONE][Embeddings] 0004/0004
# Tp 327/360
# [DONE][Embeddings] 0004/0004
# Tp 328/360
# [DONE][Embeddings] 0004/0004
# Tp 329/360
# [DONE][Embeddings] 0004/0004
# Tp 330/360
# [DONE][Embeddings] 0004/0004
# Tp 331/360
# [DONE][Embeddings] 0004/0004
# Tp 332/360
# [DONE][Embeddings] 0004/0004
# Tp 333/360
# [DONE][Embeddings] 0004/0004
# Tp 334/360
# [DONE][Embeddings] 0004/0004
# Tp 335/360
# [DONE][Embeddings] 0004/0004
# Tp 336/360
# [DONE][Embeddings] 0004/0004
# Tp 337/360
# [DONE][Embeddings] 0004/0004
# Tp 338/360
# [DONE][Embeddings] 0004/0004
# Tp 339/360
# [DONE][Embeddings] 0004/0004
# Tp 340/360
# [DONE][Embeddings] 0004/0004
# Tp 341/360
# [DONE][Embeddings] 0004/0004
# Tp 342/360
# [DONE][Embeddings] 0004/0004
# Tp 343/360
# [DONE][Embeddings] 0004/0004
# Tp 344/360
# [DONE][Embeddings] 0004/0004
# Tp 345/360
# [DONE][Embeddings] 0004/0004
# Tp 346/360
# [DONE][Embeddings] 0004/0004
# Tp 347/360
# [DONE][Embeddings] 0003/0003
# Tp 348/360
# [DONE][Embeddings] 0003/0003
# Tp 349/360
# [DONE][Embeddings] 0003/0003
# Tp 350/360
# [DONE][Embeddings] 0003/0003
# Tp 351/360
# [DONE][Embeddings] 0003/0003
# Tp 352/360
# [DONE][Embeddings] 0003/0003
# Tp 353/360
# [DONE][Embeddings] 0003/0003
# Tp 354/360
# [DONE][Embeddings] 0003/0003
# Tp 355/360
# [DONE][Embeddings] 0003/0003
# Tp 356/360
# [DONE][Embeddings] 0003/0003
# Tp 357/360
# [DONE][Embeddings] 0003/0003
# Tp 358/360
# [DONE][Embeddings] 0003/0003
# Tp 359/360
# [DONE][Embeddings] 0003/0003

# %% [markdown]
# ## (Optional) Save embeddings <a class="anchor" id="fifth-bullet"></a>

# %% [markdown]
# In order to save the embeddings to a JSON file, we have to make the content serializable.

# %% [markdown]
# Save embeddings

# %%
# Make embeddings serializable
embeddings_savable = {
    _k_tp: {
        _k_emb: _v_emb.tolist()
    for _k_emb, _v_emb
    in _v_tp.items()
    }
    for _k_tp, _v_tp
    in embeddings.items()
}

# Save embeddings
for _k_tp, _v_tp in embeddings_savable.items():
    print(f"{_k_tp + 1}".zfill(4), end='\r')
    tools_general.fn_json_write(_v_tp, f"{dir_dst_embeddings}/embeddings_tp{str(_k_tp + 1).zfill(4)}.json")
    
print(f"Saved embeddings to {dir_dst_embeddings}")
# Out:
# Saved embeddings to /results/03_Similarities_variability//embeddings

# %% [markdown]
# ## Calculate similarities <a class="anchor" id="sixth-bullet"></a>

# %% [markdown]
# Calculate similarities between all embeddings for each index of the test time series data.

# %%
similarities = dict()
similarities_low = dict()
for _k_tp, _v_tp in embeddings.items():
    print(f'Tp {_k_tp}'.ljust(50))
    sims, sims_low = tools_similarities.cosine_similarities_in_batch(_v_tp)
    similarities[_k_tp] = sims
    similarities_low[_k_tp] = sims_low
# Out:
# Tp 0
# Number of combinations/similarities: 2926/2926
# Tp 1
# Number of combinations/similarities: 2926/2926
# Tp 2
# Number of combinations/similarities: 2926/2926
# Tp 3
# Number of combinations/similarities: 2926/2926
# Tp 4
# Number of combinations/similarities: 2926/2926
# Tp 5
# Number of combinations/similarities: 2926/2926
# Tp 6
# Number of combinations/similarities: 2926/2926
# Tp 7
# Number of combinations/similarities: 2926/2926
# Tp 8
# Number of combinations/similarities: 2926/2926
# Tp 9
# Number of combinations/similarities: 2926/2926
# Tp 10
# Number of combinations/similarities: 2926/2926
# Tp 11
# Number of combinations/similarities: 2926/2926
# Tp 12
# Number of combinations/similarities: 2926/2926
# Tp 13
# Number of combinations/similarities: 2926/2926
# Tp 14
# Number of combinations/similarities: 2926/2926
# Tp 15
# Number of combinations/similarities: 2926/2926
# Tp 16
# Number of combinations/similarities: 2926/2926
# Tp 17
# Number of combinations/similarities: 2926/2926
# Tp 18
# Number of combinations/similarities: 2926/2926
# Tp 19
# Number of combinations/similarities: 2926/2926
# Tp 20
# Number of combinations/similarities: 2926/2926
# Tp 21
# Number of combinations/similarities: 2926/2926
# Tp 22
# Number of combinations/similarities: 2926/2926
# Tp 23
# Number of combinations/similarities: 2926/2926
# Tp 24
# Number of combinations/similarities: 2926/2926
# Tp 25
# Number of combinations/similarities: 2926/2926
# Tp 26
# Number of combinations/similarities: 2926/2926
# Tp 27
# Number of combinations/similarities: 2926/2926
# Tp 28
# Number of combinations/similarities: 2926/2926
# Tp 29
# Number of combinations/similarities: 2926/2926
# Tp 30
# Number of combinations/similarities: 2926/2926
# Tp 31
# Number of combinations/similarities: 2926/2926
# Tp 32
# Number of combinations/similarities: 2926/2926
# Tp 33
# Number of combinations/similarities: 2926/2926
# Tp 34
# Number of combinations/similarities: 2926/2926
# Tp 35
# Number of combinations/similarities: 2926/2926
# Tp 36
# Number of combinations/similarities: 2926/2926
# Tp 37
# Number of combinations/similarities: 2926/2926
# Tp 38
# Number of combinations/similarities: 2926/2926
# Tp 39
# Number of combinations/similarities: 2926/2926
# Tp 40
# Number of combinations/similarities: 2926/2926
# Tp 41
# Number of combinations/similarities: 2926/2926
# Tp 42
# Number of combinations/similarities: 2926/2926
# Tp 43
# Number of combinations/similarities: 2926/2926
# Tp 44
# Number of combinations/similarities: 2926/2926
# Tp 45
# Number of combinations/similarities: 2926/2926
# Tp 46
# Number of combinations/similarities: 2926/2926
# Tp 47
# Number of combinations/similarities: 2926/2926
# Tp 48
# Number of combinations/similarities: 2926/2926
# Tp 49
# Number of combinations/similarities: 2926/2926
# Tp 50
# Number of combinations/similarities: 2926/2926
# Tp 51
# Number of combinations/similarities: 2926/2926
# Tp 52
# Number of combinations/similarities: 2926/2926
# Tp 53
# Number of combinations/similarities: 2926/2926
# Tp 54
# Number of combinations/similarities: 2926/2926
# Tp 55
# Number of combinations/similarities: 2926/2926
# Tp 56
# Number of combinations/similarities: 2926/2926
# Tp 57
# Number of combinations/similarities: 2926/2926
# Tp 58
# Number of combinations/similarities: 2926/2926
# Tp 59
# Number of combinations/similarities: 2926/2926
# Tp 60
# Number of combinations/similarities: 2926/2926
# Tp 61
# Number of combinations/similarities: 2926/2926
# Tp 62
# Number of combinations/similarities: 2926/2926
# Tp 63
# Number of combinations/similarities: 2926/2926
# Tp 64
# Number of combinations/similarities: 2926/2926
# Tp 65
# Number of combinations/similarities: 2926/2926
# Tp 66
# Number of combinations/similarities: 2926/2926
# Tp 67
# Number of combinations/similarities: 2926/2926
# Tp 68
# Number of combinations/similarities: 2926/2926
# Tp 69
# Number of combinations/similarities: 2926/2926
# Tp 70
# Number of combinations/similarities: 2926/2926
# Tp 71
# Number of combinations/similarities: 2926/2926
# Tp 72
# Number of combinations/similarities: 2926/2926
# Tp 73
# Number of combinations/similarities: 2926/2926
# Tp 74
# Number of combinations/similarities: 2926/2926
# Tp 75
# Number of combinations/similarities: 2926/2926
# Tp 76
# Number of combinations/similarities: 2926/2926
# Tp 77
# Number of combinations/similarities: 2926/2926
# Tp 78
# Number of combinations/similarities: 2926/2926
# Tp 79
# Number of combinations/similarities: 2926/2926
# Tp 80
# Number of combinations/similarities: 2926/2926
# Tp 81
# Number of combinations/similarities: 2926/2926
# Tp 82
# Number of combinations/similarities: 2926/2926
# Tp 83
# Number of combinations/similarities: 2926/2926
# Tp 84
# Number of combinations/similarities: 2926/2926
# Tp 85
# Number of combinations/similarities: 2926/2926
# Tp 86
# Number of combinations/similarities: 2926/2926
# Tp 87
# Number of combinations/similarities: 2926/2926
# Tp 88
# Number of combinations/similarities: 2926/2926
# Tp 89
# Number of combinations/similarities: 2926/2926
# Tp 90
# Number of combinations/similarities: 2926/2926
# Tp 91
# Number of combinations/similarities: 2926/2926
# Tp 92
# Number of combinations/similarities: 2926/2926
# Tp 93
# Number of combinations/similarities: 2926/2926
# Tp 94
# Number of combinations/similarities: 2926/2926
# Tp 95
# Number of combinations/similarities: 2926/2926
# Tp 96
# Number of combinations/similarities: 2926/2926
# Tp 97
# Number of combinations/similarities: 2926/2926
# Tp 98
# Number of combinations/similarities: 2926/2926
# Tp 99
# Number of combinations/similarities: 2926/2926
# Tp 100
# Number of combinations/similarities: 2926/2926
# Tp 101
# Number of combinations/similarities: 2926/2926
# Tp 102
# Number of combinations/similarities: 2926/2926
# Tp 103
# Number of combinations/similarities: 2926/2926
# Tp 104
# Number of combinations/similarities: 2926/2926
# Tp 105
# Number of combinations/similarities: 2926/2926
# Tp 106
# Number of combinations/similarities: 2926/2926
# Tp 107
# Number of combinations/similarities: 2926/2926
# Tp 108
# Number of combinations/similarities: 2926/2926
# Tp 109
# Number of combinations/similarities: 2926/2926
# Tp 110
# Number of combinations/similarities: 2926/2926
# Tp 111
# Number of combinations/similarities: 2926/2926
# Tp 112
# Number of combinations/similarities: 2926/2926
# Tp 113
# Number of combinations/similarities: 2926/2926
# Tp 114
# Number of combinations/similarities: 2926/2926
# Tp 115
# Number of combinations/similarities: 2926/2926
# Tp 116
# Number of combinations/similarities: 2926/2926
# Tp 117
# Number of combinations/similarities: 2926/2926
# Tp 118
# Number of combinations/similarities: 2926/2926
# Tp 119
# Number of combinations/similarities: 2926/2926
# Tp 120
# Number of combinations/similarities: 2926/2926
# Tp 121
# Number of combinations/similarities: 2926/2926
# Tp 122
# Number of combinations/similarities: 2926/2926
# Tp 123
# Number of combinations/similarities: 2926/2926
# Tp 124
# Number of combinations/similarities: 2926/2926
# Tp 125
# Number of combinations/similarities: 2926/2926
# Tp 126
# Number of combinations/similarities: 2926/2926
# Tp 127
# Number of combinations/similarities: 2926/2926
# Tp 128
# Number of combinations/similarities: 2926/2926
# Tp 129
# Number of combinations/similarities: 2926/2926
# Tp 130
# Number of combinations/similarities: 2926/2926
# Tp 131
# Number of combinations/similarities: 2926/2926
# Tp 132
# Number of combinations/similarities: 2926/2926
# Tp 133
# Number of combinations/similarities: 2926/2926
# Tp 134
# Number of combinations/similarities: 2926/2926
# Tp 135
# Number of combinations/similarities: 2926/2926
# Tp 136
# Number of combinations/similarities: 2926/2926
# Tp 137
# Number of combinations/similarities: 2926/2926
# Tp 138
# Number of combinations/similarities: 2926/2926
# Tp 139
# Number of combinations/similarities: 2926/2926
# Tp 140
# Number of combinations/similarities: 2926/2926
# Tp 141
# Number of combinations/similarities: 2926/2926
# Tp 142
# Number of combinations/similarities: 2926/2926
# Tp 143
# Number of combinations/similarities: 2926/2926
# Tp 144
# Number of combinations/similarities: 2926/2926
# Tp 145
# Number of combinations/similarities: 2926/2926
# Tp 146
# Number of combinations/similarities: 2926/2926
# Tp 147
# Number of combinations/similarities: 2926/2926
# Tp 148
# Number of combinations/similarities: 2926/2926
# Tp 149
# Number of combinations/similarities: 2926/2926
# Tp 150
# Number of combinations/similarities: 2926/2926
# Tp 151
# Number of combinations/similarities: 2926/2926
# Tp 152
# Number of combinations/similarities: 2926/2926
# Tp 153
# Number of combinations/similarities: 2926/2926
# Tp 154
# Number of combinations/similarities: 2926/2926
# Tp 155
# Number of combinations/similarities: 2926/2926
# Tp 156
# Number of combinations/similarities: 2926/2926
# Tp 157
# Number of combinations/similarities: 2926/2926
# Tp 158
# Number of combinations/similarities: 2926/2926
# Tp 159
# Number of combinations/similarities: 2926/2926
# Tp 160
# Number of combinations/similarities: 2926/2926
# Tp 161
# Number of combinations/similarities: 2926/2926
# Tp 162
# Number of combinations/similarities: 2926/2926
# Tp 163
# Number of combinations/similarities: 2926/2926
# Tp 164
# Number of combinations/similarities: 2926/2926
# Tp 165
# Number of combinations/similarities: 2926/2926
# Tp 166
# Number of combinations/similarities: 2926/2926
# Tp 167
# Number of combinations/similarities: 2926/2926
# Tp 168
# Number of combinations/similarities: 2926/2926
# Tp 169
# Number of combinations/similarities: 2926/2926
# Tp 170
# Number of combinations/similarities: 2926/2926
# Tp 171
# Number of combinations/similarities: 2926/2926
# Tp 172
# Number of combinations/similarities: 2926/2926
# Tp 173
# Number of combinations/similarities: 2926/2926
# Tp 174
# Number of combinations/similarities: 2926/2926
# Tp 175
# Number of combinations/similarities: 2926/2926
# Tp 176
# Number of combinations/similarities: 2926/2926
# Tp 177
# Number of combinations/similarities: 2926/2926
# Tp 178
# Number of combinations/similarities: 2926/2926
# Tp 179
# Number of combinations/similarities: 2926/2926
# Tp 180
# Number of combinations/similarities: 2926/2926
# Tp 181
# Number of combinations/similarities: 2926/2926
# Tp 182
# Number of combinations/similarities: 2926/2926
# Tp 183
# Number of combinations/similarities: 2926/2926
# Tp 184
# Number of combinations/similarities: 2926/2926
# Tp 185
# Number of combinations/similarities: 2926/2926
# Tp 186
# Number of combinations/similarities: 2926/2926
# Tp 187
# Number of combinations/similarities: 2926/2926
# Tp 188
# Number of combinations/similarities: 2926/2926
# Tp 189
# Number of combinations/similarities: 2926/2926
# Tp 190
# Number of combinations/similarities: 2926/2926
# Tp 191
# Number of combinations/similarities: 2926/2926
# Tp 192
# Number of combinations/similarities: 2926/2926
# Tp 193
# Number of combinations/similarities: 2926/2926
# Tp 194
# Number of combinations/similarities: 2926/2926
# Tp 195
# Number of combinations/similarities: 2926/2926
# Tp 196
# Number of combinations/similarities: 2926/2926
# Tp 197
# Number of combinations/similarities: 2926/2926
# Tp 198
# Number of combinations/similarities: 2926/2926
# Tp 199
# Number of combinations/similarities: 2926/2926
# Tp 200
# Number of combinations/similarities: 2926/2926
# Tp 201
# Number of combinations/similarities: 2926/2926
# Tp 202
# Number of combinations/similarities: 2926/2926
# Tp 203
# Number of combinations/similarities: 2926/2926
# Tp 204
# Number of combinations/similarities: 2926/2926
# Tp 205
# Number of combinations/similarities: 2926/2926
# Tp 206
# Number of combinations/similarities: 2926/2926
# Tp 207
# Number of combinations/similarities: 2926/2926
# Tp 208
# Number of combinations/similarities: 2926/2926
# Tp 209
# Number of combinations/similarities: 2926/2926
# Tp 210
# Number of combinations/similarities: 2926/2926
# Tp 211
# Number of combinations/similarities: 2926/2926
# Tp 212
# Number of combinations/similarities: 2926/2926
# Tp 213
# Number of combinations/similarities: 2926/2926
# Tp 214
# Number of combinations/similarities: 2926/2926
# Tp 215
# Number of combinations/similarities: 2926/2926
# Tp 216
# Number of combinations/similarities: 2926/2926
# Tp 217
# Number of combinations/similarities: 2926/2926
# Tp 218
# Number of combinations/similarities: 2926/2926
# Tp 219
# Number of combinations/similarities: 2926/2926
# Tp 220
# Number of combinations/similarities: 2926/2926
# Tp 221
# Number of combinations/similarities: 2926/2926
# Tp 222
# Number of combinations/similarities: 2926/2926
# Tp 223
# Number of combinations/similarities: 2926/2926
# Tp 224
# Number of combinations/similarities: 2926/2926
# Tp 225
# Number of combinations/similarities: 2926/2926
# Tp 226
# Number of combinations/similarities: 2926/2926
# Tp 227
# Number of combinations/similarities: 2926/2926
# Tp 228
# Number of combinations/similarities: 2926/2926
# Tp 229
# Number of combinations/similarities: 2926/2926
# Tp 230
# Number of combinations/similarities: 2926/2926
# Tp 231
# Number of combinations/similarities: 2926/2926
# Tp 232
# Number of combinations/similarities: 2926/2926
# Tp 233
# Number of combinations/similarities: 2926/2926
# Tp 234
# Number of combinations/similarities: 2926/2926
# Tp 235
# Number of combinations/similarities: 2926/2926
# Tp 236
# Number of combinations/similarities: 2926/2926
# Tp 237
# Number of combinations/similarities: 2926/2926
# Tp 238
# Number of combinations/similarities: 2926/2926
# Tp 239
# Number of combinations/similarities: 2926/2926
# Tp 240
# Number of combinations/similarities: 2926/2926
# Tp 241
# Number of combinations/similarities: 2926/2926
# Tp 242
# Number of combinations/similarities: 2926/2926
# Tp 243
# Number of combinations/similarities: 2926/2926
# Tp 244
# Number of combinations/similarities: 2926/2926
# Tp 245
# Number of combinations/similarities: 2926/2926
# Tp 246
# Number of combinations/similarities: 2926/2926
# Tp 247
# Number of combinations/similarities: 2926/2926
# Tp 248
# Number of combinations/similarities: 2926/2926
# Tp 249
# Number of combinations/similarities: 2926/2926
# Tp 250
# Number of combinations/similarities: 2926/2926
# Tp 251
# Number of combinations/similarities: 2926/2926
# Tp 252
# Number of combinations/similarities: 2926/2926
# Tp 253
# Number of combinations/similarities: 2926/2926
# Tp 254
# Number of combinations/similarities: 2926/2926
# Tp 255
# Number of combinations/similarities: 2926/2926
# Tp 256
# Number of combinations/similarities: 2926/2926
# Tp 257
# Number of combinations/similarities: 2926/2926
# Tp 258
# Number of combinations/similarities: 2926/2926
# Tp 259
# Number of combinations/similarities: 2926/2926
# Tp 260
# Number of combinations/similarities: 2926/2926
# Tp 261
# Number of combinations/similarities: 2926/2926
# Tp 262
# Number of combinations/similarities: 2926/2926
# Tp 263
# Number of combinations/similarities: 2926/2926
# Tp 264
# Number of combinations/similarities: 2926/2926
# Tp 265
# Number of combinations/similarities: 2926/2926
# Tp 266
# Number of combinations/similarities: 2926/2926
# Tp 267
# Number of combinations/similarities: 2850/2850
# Tp 268
# Number of combinations/similarities: 2850/2850
# Tp 269
# Number of combinations/similarities: 2850/2850
# Tp 270
# Number of combinations/similarities: 2850/2850
# Tp 271
# Number of combinations/similarities: 2850/2850
# Tp 272
# Number of combinations/similarities: 2850/2850
# Tp 273
# Number of combinations/similarities: 2775/2775
# Tp 274
# Number of combinations/similarities: 2775/2775
# Tp 275
# Number of combinations/similarities: 2775/2775
# Tp 276
# Number of combinations/similarities: 2775/2775
# Tp 277
# Number of combinations/similarities: 2775/2775
# Tp 278
# Number of combinations/similarities: 2775/2775
# Tp 279
# Number of combinations/similarities: 2775/2775
# Tp 280
# Number of combinations/similarities: 2775/2775
# Tp 281
# Number of combinations/similarities: 2775/2775
# Tp 282
# Number of combinations/similarities: 2775/2775
# Tp 283
# Number of combinations/similarities: 2775/2775
# Tp 284
# Number of combinations/similarities: 2775/2775
# Tp 285
# Number of combinations/similarities: 2775/2775
# Tp 286
# Number of combinations/similarities: 2775/2775
# Tp 287
# Number of combinations/similarities: 2701/2701
# Tp 288
# Number of combinations/similarities: 2628/2628
# Tp 289
# Number of combinations/similarities: 2628/2628
# Tp 290
# Number of combinations/similarities: 2628/2628
# Tp 291
# Number of combinations/similarities: 2628/2628
# Tp 292
# Number of combinations/similarities: 2628/2628
# Tp 293
# Number of combinations/similarities: 2628/2628
# Tp 294
# Number of combinations/similarities: 2628/2628
# Tp 295
# Number of combinations/similarities: 2628/2628
# Tp 296
# Number of combinations/similarities: 2628/2628
# Tp 297
# Number of combinations/similarities: 2556/2556
# Tp 298
# Number of combinations/similarities: 2556/2556
# Tp 299
# Number of combinations/similarities: 2556/2556
# Tp 300
# Number of combinations/similarities: 2556/2556
# Tp 301
# Number of combinations/similarities: 2556/2556
# Tp 302
# Number of combinations/similarities: 2556/2556
# Tp 303
# Number of combinations/similarities: 2556/2556
# Tp 304
# Number of combinations/similarities: 2556/2556
# Tp 305
# Number of combinations/similarities: 2556/2556
# Tp 306
# Number of combinations/similarities: 2556/2556
# Tp 307
# Number of combinations/similarities: 2556/2556
# Tp 308
# Number of combinations/similarities: 2556/2556
# Tp 309
# Number of combinations/similarities: 2556/2556
# Tp 310
# Number of combinations/similarities: 2556/2556
# Tp 311
# Number of combinations/similarities: 2485/2485
# Tp 312
# Number of combinations/similarities: 2485/2485
# Tp 313
# Number of combinations/similarities: 2415/2415
# Tp 314
# Number of combinations/similarities: 2415/2415
# Tp 315
# Number of combinations/similarities: 2415/2415
# Tp 316
# Number of combinations/similarities: 2415/2415
# Tp 317
# Number of combinations/similarities: 2415/2415
# Tp 318
# Number of combinations/similarities: 2415/2415
# Tp 319
# Number of combinations/similarities: 2346/2346
# Tp 320
# Number of combinations/similarities: 2346/2346
# Tp 321
# Number of combinations/similarities: 2278/2278
# Tp 322
# Number of combinations/similarities: 2211/2211
# Tp 323
# Number of combinations/similarities: 2145/2145
# Tp 324
# Number of combinations/similarities: 2145/2145
# Tp 325
# Number of combinations/similarities: 2145/2145
# Tp 326
# Number of combinations/similarities: 2145/2145
# Tp 327
# Number of combinations/similarities: 2145/2145
# Tp 328
# Number of combinations/similarities: 2145/2145
# Tp 329
# Number of combinations/similarities: 2145/2145
# Tp 330
# Number of combinations/similarities: 2145/2145
# Tp 331
# Number of combinations/similarities: 2080/2080
# Tp 332
# Number of combinations/similarities: 2016/2016
# Tp 333
# Number of combinations/similarities: 2016/2016
# Tp 334
# Number of combinations/similarities: 2016/2016
# Tp 335
# Number of combinations/similarities: 2016/2016
# Tp 336
# Number of combinations/similarities: 2016/2016
# Tp 337
# Number of combinations/similarities: 2016/2016
# Tp 338
# Number of combinations/similarities: 2016/2016
# Tp 339
# Number of combinations/similarities: 2016/2016
# Tp 340
# Number of combinations/similarities: 2016/2016
# Tp 341
# Number of combinations/similarities: 1953/1953
# Tp 342
# Number of combinations/similarities: 1953/1953
# Tp 343
# Number of combinations/similarities: 1953/1953
# Tp 344
# Number of combinations/similarities: 1953/1953
# Tp 345
# Number of combinations/similarities: 1953/1953
# Tp 346
# Number of combinations/similarities: 1953/1953
# Tp 347
# Number of combinations/similarities: 1770/1770
# Tp 348
# Number of combinations/similarities: 1770/1770
# Tp 349
# Number of combinations/similarities: 1770/1770
# Tp 350
# Number of combinations/similarities: 1770/1770
# Tp 351
# Number of combinations/similarities: 1770/1770
# Tp 352
# Number of combinations/similarities: 1770/1770
# Tp 353
# Number of combinations/similarities: 1770/1770
# Tp 354
# Number of combinations/similarities: 1770/1770
# Tp 355
# Number of combinations/similarities: 1770/1770
# Tp 356
# Number of combinations/similarities: 1711/1711
# Tp 357
# Number of combinations/similarities: 1653/1653
# Tp 358
# Number of combinations/similarities: 1653/1653
# Tp 359
# Number of combinations/similarities: 1653/1653

# %% [markdown]
# ## (Optional) Save similarities <a class="anchor" id="seventh-bullet"></a>

# %% [markdown]
# Save similarities

# %%
# The similarities dictionary already has lists as values,
# however, lists are with floats and not JSON serializable.
# Therefore, convert each list of similarities to a numpy
# array and back to a list.
similarities_savable = {
    _k_tp: np.array(_v_tp).tolist()
    for _k_tp, _v_tp
    in similarities.items()
}

# Save similarities
for _k_tp, _v_tp in similarities_savable.items():
    print(f"{_k_tp + 1}".zfill(4), end='\r')
    tools_general.fn_json_write(_v_tp, f"{dir_dst_similarities}/similarities_tp{str(_k_tp + 1).zfill(4)}.json")

print(f"Saved similarities to {dir_dst_similarities}")
# Out:
# Saved similarities to /results/03_Similarities_variability//similarities

# %% [markdown]
# Load similarities

# %%
paths_similarities = list(sorted(glob.glob(
    f"{dir_dst_similarities}/similarities_tp*.json")))
similarities_loaded = dict()

for i in range(len(paths_similarities)):
    print(f"{i + 1}".zfill(4), end='\r')
    content = tools_general.fn_json_load(paths_similarities[i])
    similarities_loaded[i] = content
    
print(f"Loaded from {dir_dst_similarities}")
# Out:
# Loaded from /results/03_Similarities_variability//similarities

# %% [markdown]
# ## Plot distribution of similarities at selected sequence indices<a class="anchor" id="eigth-bullet"></a>

# %% [markdown]
# Plot distributions of similarities as histograms for selected sequence indices. As parameters, give similarities with corresponding colors and labels for plotting.

# %%
tools_plot.plot_distribution_similarities(
    [similarities[0], similarities[179], similarities[359]],
    [(193/255, 216/255, 47/255), (19/255, 110/255, 142/255), (68/255, 24/255, 83/255)],
    ['0 min', '720 min', '1440 min'],
    path_save=f'{path_dst}/demo_distributions_similarities_hist.svg')

# %% [markdown]
# ## Plot distribution of similarities for complete sequence<a class="anchor" id="ninth-bullet"></a>

# %% [markdown]
# Plot distributions of similarities for a complete sequence.

# %%
tools_plot.plot_distribution_similarities_multiple(similarities,
                                                   path_save=f'{path_dst}/demo_distributions_similarities.svg')
